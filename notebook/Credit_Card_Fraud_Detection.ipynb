# %% [markdown]
# <a href="https://colab.research.google.com/github/buterajacques1/Credit-Card-Fraud-Detection-Predictive-Model/blob/main/notebook/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependencies

# %%
#Import Necessary Libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Conv1D, Dropout, MaxPool1D, BatchNormalization
from IPython.display import SVG
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import model_to_dot, plot_model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.regularizers import l1, l2
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly import tools
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from sklearn.metrics import confusion_matrix, classification_report

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/credit_data.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unblanced

# %% [markdown]
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrames

# %%
df = pd.concat([legit_sample, fraud], axis=0)

# %%
df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 17652    28840.0  1.297184 -0.811037  1.465942 -0.686694 -1.824655 -0.327510
# 171825  120837.0 -0.373593  1.108399 -1.065052  0.700649  2.458293  1.364275
# 112298   72600.0 -1.545811  1.713159  0.085753 -0.883326  0.261215 -0.097459
# 114628   73557.0  1.280718  0.365857  0.086860  0.566550 -0.056862 -0.747054
# 85825    60955.0 -0.989250  0.651069 -0.998413 -1.408951  2.812663  3.547332
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 17652  -1.427698  0.175075 -0.437639  ...  0.499007  1.367446 -0.067153
# 171825  1.010256  0.349546 -0.859182  ...  0.149238  0.645738 -0.167307
# 112298 -0.188625  0.095020 -0.901925  ...  0.667820 -0.958422  0.010809
# 114628  0.130514 -0.209522 -0.033425  ... -0.310838 -0.877579  0.048488
# 85825  -0.818144 -1.795880 -0.592282  ... -1.251679  0.473073  0.358968
#
#              V24       V25       V26       V27       V28  Amount  Class
# 17652   0.577462  0.255543 -0.072084  0.054238  0.024684    9.99      0
# 171825 -1.080766 -0.165317 -0.317655  0.131491  0.177416    7.41      0
# 112298 -0.907911 -0.209923 -0.096835 -0.276654 -0.009498    0.99      0
# 114628 -0.174291  0.307948  0.124719 -0.020739  0.028072    8.99      0
# 85825   1.024587 -0.263910  0.288005  0.122177  0.164521    1.00      0
#
# [5 rows x 31 columns]

# %%
df.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28  Amount  Class
# 279863 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00      1
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76      1
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89      1
# 281144 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00      1
# 281674 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53      1
#
# [5 rows x 31 columns]

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94296.780488 -0.068343  0.023106 -0.030780 -0.006295  0.051524
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.063830  0.137848 -0.018896 -0.016618  ...  0.027446 -0.038744
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.043810 -0.002193 -0.000675 -0.014632  0.016149 -0.030331 -0.002533
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0      104.667825
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Finding Correlation

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    df = df.dropna(axis='columns', how='all')  # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for Credit Card Fraud Dataset', fontsize=15)
    plt.show()

# %%
plotCorrelationMatrix(df, 8)

# %% [markdown]
# Scatter and Density Plot

# %%
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna(axis='columns', how='all')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
plotScatterMatrix(df, 20, 8)

# %% [markdown]
# SECTION 2: Data Preprocessing

# %%
# Define features x and y
x = df.drop(columns='Class', axis=1)
y = df['Class']

# %%
print(x)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 17652    28840.0  1.297184 -0.811037  1.465942 -0.686694 -1.824655 -0.327510
# 171825  120837.0 -0.373593  1.108399 -1.065052  0.700649  2.458293  1.364275
# 112298   72600.0 -1.545811  1.713159  0.085753 -0.883326  0.261215 -0.097459
# 114628   73557.0  1.280718  0.365857  0.086860  0.566550 -0.056862 -0.747054
# 85825    60955.0 -0.989250  0.651069 -0.998413 -1.408951  2.812663  3.547332
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 17652  -1.427698  0.175075 -0.437639  ...  0.097367  0.499007  1.367446
# 171825  1.010256  0.349546 -0.859182  ... -0.171237  0.149238  0.645738
# 112298 -0.188625  0.095020 -0.901925  ... -0.466765  0.667820 -0.958422
# 114628  0.130514 -0.209522 -0.033425  ... -0.005549 -0.310838 -0.877579
# 85825  -0.818144 -1.795880 -0.592282  ...  0.504656 -1.251679  0.473073
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  1.252967  0.778584 -0.319189
# 280143 -1.413170  0.248525 -1.127396  ...  0.226138  0.370612  0.028234
# 280149 -2.234739  1.210158 -0.652250  ...  0.247968  0.751826  0.834108
# 281144 -2.208002  1.058733 -1.632333  ...  0.306271  0.583276 -0.269209
# 281674  0.223050 -0.068384  0.577829  ... -0.017652 -0.164350 -0.295135
#
#              V23       V24       V25       V26       V27       V28  Amount
# 17652  -0.067153  0.577462  0.255543 -0.072084  0.054238  0.024684    9.99
# 171825 -0.167307 -1.080766 -0.165317 -0.317655  0.131491  0.177416    7.41
# 112298  0.010809 -0.907911 -0.209923 -0.096835 -0.276654 -0.009498    0.99
# 114628  0.048488 -0.174291  0.307948  0.124719 -0.020739  0.028072    8.99
# 85825   0.358968  1.024587 -0.263910  0.288005  0.122177  0.164521    1.00
# ...          ...       ...       ...       ...       ...       ...     ...
# 279863  0.639419 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00
# 280143 -0.145640 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76
# 280149  0.190944  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89
# 281144 -0.456108 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00
# 281674 -0.072173 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53
#
# [984 rows x 30 columns]

# %%
print(y)
# Out:
# 17652     0
# 171825    0
# 112298    0
# 114628    0
# 85825     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
print(x.shape, y.shape)
# Out:
# (984, 30) (984,)

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (787, 30) (787,) (197, 30) (197,)

# %% [markdown]
# Train Model without Optimization

# %%
epochs = 50
model = Sequential()
# Add convolution 2D
model.add(Conv1D(filters=32,kernel_size=2,activation='relu',input_shape=(30,1)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv1D(filters=64,kernel_size=2,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation='sigmoid'))

# %%
# Compile the model without any optimization technique
model.compile(loss=categorical_crossentropy,
              metrics=['accuracy'])
model.save('saved_models/model1.pkl')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 29, 32)            96
#
#  batch_normalization (Batch  (None, 29, 32)            128
#  Normalization)
#
#  dropout (Dropout)           (None, 29, 32)            0
#
#  conv1d_1 (Conv1D)           (None, 28, 64)            4160
#
#  batch_normalization_1 (Bat  (None, 28, 64)            256
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 28, 64)            0
#
#  flatten (Flatten)           (None, 1792)              0
#
#  dense (Dense)               (None, 64)                114752
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 119457 (466.63 KB)
# Trainable params: 119265 (465.88 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X_train,y_train,epochs=epochs,validation_data=(X_test,y_test),verbose=1)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: SyntaxWarning:
#
# In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.6680
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: SyntaxWarning:
#
# In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
# 25/25 [==============================] - 3s 36ms/step - loss: 0.0000e+00 - accuracy: 0.6696 - val_loss: 0.0000e+00 - val_accuracy: 0.7462
# Epoch 2/50
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - accuracy: 0.7001 - val_loss: 0.0000e+00 - val_accuracy: 0.8020
# Epoch 3/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.7255 - val_loss: 0.0000e+00 - val_accuracy: 0.8477
# Epoch 4/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - accuracy: 0.7205 - val_loss: 0.0000e+00 - val_accuracy: 0.8122
# Epoch 5/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - accuracy: 0.7230 - val_loss: 0.0000e+00 - val_accuracy: 0.8071
# Epoch 6/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - accuracy: 0.7116 - val_loss: 0.0000e+00 - val_accuracy: 0.7868
# Epoch 7/50
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0000e+00 - accuracy: 0.7078 - val_loss: 0.0000e+00 - val_accuracy: 0.7766
# Epoch 8/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.7001 - val_loss: 0.0000e+00 - val_accuracy: 0.7208
# Epoch 9/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.7141 - val_loss: 0.0000e+00 - val_accuracy: 0.7005
# Epoch 10/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6760 - val_loss: 0.0000e+00 - val_accuracy: 0.7056
# Epoch 13/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6811 - val_loss: 0.0000e+00 - val_accuracy: 0.7056
# Epoch 14/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - accuracy: 0.6747 - val_loss: 0.0000e+00 - val_accuracy: 0.7056
# Epoch 15/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 0.6836 - val_loss: 0.0000e+00 - val_accuracy: 0.7056
# Epoch 16/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6633 - val_loss: 0.0000e+00 - val_accuracy: 0.6954
# Epoch 17/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6785 - val_loss: 0.0000e+00 - val_accuracy: 0.7005
# Epoch 18/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6658 - val_loss: 0.0000e+00 - val_accuracy: 0.6954
# Epoch 19/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 0.6760 - val_loss: 0.0000e+00 - val_accuracy: 0.6954
# Epoch 20/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 0.6595 - val_loss: 0.0000e+00 - val_accuracy: 0.6904
# Epoch 21/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 0.6518 - val_loss: 0.0000e+00 - val_accuracy: 0.6904
# Epoch 22/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6544 - val_loss: 0.0000e+00 - val_accuracy: 0.6853
# Epoch 23/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 0.6595 - val_loss: 0.0000e+00 - val_accuracy: 0.6853
# Epoch 24/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6595 - val_loss: 0.0000e+00 - val_accuracy: 0.6853
# Epoch 25/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6544 - val_loss: 0.0000e+00 - val_accuracy: 0.6802
# Epoch 26/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6493 - val_loss: 0.0000e+00 - val_accuracy: 0.6802
# Epoch 27/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6429 - val_loss: 0.0000e+00 - val_accuracy: 0.6548
# Epoch 28/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6468 - val_loss: 0.0000e+00 - val_accuracy: 0.6548
# Epoch 29/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 0.6417 - val_loss: 0.0000e+00 - val_accuracy: 0.6599
# Epoch 30/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6468 - val_loss: 0.0000e+00 - val_accuracy: 0.6497
# Epoch 31/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 0.6468 - val_loss: 0.0000e+00 - val_accuracy: 0.6447
# Epoch 32/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6468 - val_loss: 0.0000e+00 - val_accuracy: 0.6701
# Epoch 33/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6493 - val_loss: 0.0000e+00 - val_accuracy: 0.6447
# Epoch 34/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - accuracy: 0.6531 - val_loss: 0.0000e+00 - val_accuracy: 0.6193
# Epoch 35/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 0.6468 - val_loss: 0.0000e+00 - val_accuracy: 0.6142
# Epoch 36/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 0.6518 - val_loss: 0.0000e+00 - val_accuracy: 0.6142
# Epoch 37/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 0.6455 - val_loss: 0.0000e+00 - val_accuracy: 0.6142
# Epoch 38/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - accuracy: 0.6531 - val_loss: 0.0000e+00 - val_accuracy: 0.6142
# Epoch 39/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6506 - val_loss: 0.0000e+00 - val_accuracy: 0.6142
# Epoch 40/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6455 - val_loss: 0.0000e+00 - val_accuracy: 0.6142
# Epoch 41/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6442 - val_loss: 0.0000e+00 - val_accuracy: 0.6142
# Epoch 42/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - accuracy: 0.6404 - val_loss: 0.0000e+00 - val_accuracy: 0.6142
# Epoch 43/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6493 - val_loss: 0.0000e+00 - val_accuracy: 0.6142
# Epoch 44/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.6442 - val_loss: 0.0000e+00 - val_accuracy: 0.6142
# Epoch 45/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0000e+00 - accuracy: 0.6607 - val_loss: 0.0000e+00 - val_accuracy: 0.6091
# Epoch 46/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - accuracy: 0.6531 - val_loss: 0.0000e+00 - val_accuracy: 0.6091
# Epoch 47/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.6404 - val_loss: 0.0000e+00 - val_accuracy: 0.6091
# Epoch 48/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.6391 - val_loss: 0.0000e+00 - val_accuracy: 0.6091
# Epoch 49/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.6315 - val_loss: 0.0000e+00 - val_accuracy: 0.6091
# Epoch 50/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0000e+00 - accuracy: 0.6417 - val_loss: 0.0000e+00 - val_accuracy: 0.6142

# %%
# Print the final accuracy
_, train_accuracy = model.evaluate(X_train, y_train)
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Training Accuracy: {train_accuracy * 100:.2f}%')
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.6150
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.6142
# Training Accuracy: 61.50%
# Test Accuracy: 61.42%

# %%
# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

# %% [markdown]
# Model Training with Optimization Techniques
#
# Adam Optimization

# %%
model2 = Sequential()
# Add convolution 2D
model2.add(Conv1D(filters=32,kernel_size=2,activation='relu',input_shape=(30,1)))
model2.add(BatchNormalization())
model2.add(Dropout(0.2))

model2.add(Conv1D(filters=64,kernel_size=2,activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.5))

model2.add(Flatten())
model2.add(Dense(64,activation='relu'))
model2.add(Dropout(0.5))

model2.add(Dense(1,activation='sigmoid'))
model2.compile(optimizer=Adam(lr=0.00005),loss='binary_crossentropy',metrics=['accuracy'])
model2.save('saved_models/model2.pkl')
model2.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 29, 32)            96
#
#  batch_normalization_2 (Bat  (None, 29, 32)            128
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 29, 32)            0
#
#  conv1d_3 (Conv1D)           (None, 28, 64)            4160
#
#  batch_normalization_3 (Bat  (None, 28, 64)            256
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 28, 64)            0
#
#  flatten_1 (Flatten)         (None, 1792)              0
#
#  dense_2 (Dense)             (None, 64)                114752
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 119457 (466.63 KB)
# Trainable params: 119265 (465.88 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
adam_model = model2.fit(X_train,y_train,epochs=epochs,validation_data=(X_test,y_test),verbose=1)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 2s 21ms/step - loss: 0.4261 - accuracy: 0.8424 - val_loss: 0.4759 - val_accuracy: 0.6548
# Epoch 2/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.2641 - accuracy: 0.9276 - val_loss: 0.3918 - val_accuracy: 0.9086
# Epoch 3/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.2235 - accuracy: 0.9250 - val_loss: 0.3000 - val_accuracy: 0.8985
# Epoch 4/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.2358 - accuracy: 0.9199 - val_loss: 0.2688 - val_accuracy: 0.9086
# Epoch 5/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.2221 - accuracy: 0.9199 - val_loss: 0.2251 - val_accuracy: 0.9086
# Epoch 6/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1994 - accuracy: 0.9301 - val_loss: 0.2356 - val_accuracy: 0.9137
# Epoch 7/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1964 - accuracy: 0.9149 - val_loss: 0.2120 - val_accuracy: 0.9086
# Epoch 8/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1951 - accuracy: 0.9288 - val_loss: 0.2076 - val_accuracy: 0.9239
# Epoch 9/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1629 - accuracy: 0.9327 - val_loss: 0.2060 - val_accuracy: 0.9137
# Epoch 10/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1862 - accuracy: 0.9352 - val_loss: 0.1912 - val_accuracy: 0.9239
# Epoch 11/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1852 - accuracy: 0.9352 - val_loss: 0.1958 - val_accuracy: 0.9340
# Epoch 12/50
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1849 - accuracy: 0.9390 - val_loss: 0.1855 - val_accuracy: 0.9188
# Epoch 13/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1450 - accuracy: 0.9441 - val_loss: 0.1743 - val_accuracy: 0.9289
# Epoch 14/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1606 - accuracy: 0.9352 - val_loss: 0.1752 - val_accuracy: 0.9289
# Epoch 15/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1406 - accuracy: 0.9492 - val_loss: 0.1746 - val_accuracy: 0.9289
# Epoch 16/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1635 - accuracy: 0.9390 - val_loss: 0.1828 - val_accuracy: 0.9239
# Epoch 17/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1678 - accuracy: 0.9390 - val_loss: 0.1778 - val_accuracy: 0.9239
# Epoch 18/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1459 - accuracy: 0.9454 - val_loss: 0.1726 - val_accuracy: 0.9391
# Epoch 19/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1559 - accuracy: 0.9479 - val_loss: 0.1802 - val_accuracy: 0.9391
# Epoch 20/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1448 - accuracy: 0.9428 - val_loss: 0.1832 - val_accuracy: 0.9289
# Epoch 21/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1573 - accuracy: 0.9403 - val_loss: 0.1748 - val_accuracy: 0.9340
# Epoch 22/50
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1792 - accuracy: 0.9352 - val_loss: 0.1732 - val_accuracy: 0.9391
# Epoch 23/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.1440 - accuracy: 0.9466 - val_loss: 0.1798 - val_accuracy: 0.9391
# Epoch 24/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.1419 - accuracy: 0.9466 - val_loss: 0.1763 - val_accuracy: 0.9391
# Epoch 25/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1441 - accuracy: 0.9390 - val_loss: 0.1718 - val_accuracy: 0.9340
# Epoch 26/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.1329 - accuracy: 0.9530 - val_loss: 0.1647 - val_accuracy: 0.9340
# Epoch 27/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.1477 - accuracy: 0.9428 - val_loss: 0.1818 - val_accuracy: 0.9391
# Epoch 28/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.1440 - accuracy: 0.9479 - val_loss: 0.1750 - val_accuracy: 0.9340
# Epoch 29/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.1334 - accuracy: 0.9504 - val_loss: 0.1686 - val_accuracy: 0.9340
# Epoch 30/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1328 - accuracy: 0.9479 - val_loss: 0.1687 - val_accuracy: 0.9340
# Epoch 31/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1269 - accuracy: 0.9517 - val_loss: 0.1630 - val_accuracy: 0.9340
# Epoch 32/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1424 - accuracy: 0.9555 - val_loss: 0.1677 - val_accuracy: 0.9391
# Epoch 33/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1168 - accuracy: 0.9479 - val_loss: 0.1707 - val_accuracy: 0.9289
# Epoch 34/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1434 - accuracy: 0.9504 - val_loss: 0.1712 - val_accuracy: 0.9289
# Epoch 35/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1385 - accuracy: 0.9530 - val_loss: 0.1844 - val_accuracy: 0.9340
# Epoch 36/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1206 - accuracy: 0.9581 - val_loss: 0.1882 - val_accuracy: 0.9340
# Epoch 37/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1284 - accuracy: 0.9530 - val_loss: 0.1740 - val_accuracy: 0.9340
# Epoch 38/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1334 - accuracy: 0.9466 - val_loss: 0.1808 - val_accuracy: 0.9442
# Epoch 39/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1169 - accuracy: 0.9581 - val_loss: 0.1717 - val_accuracy: 0.9340
# Epoch 40/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1234 - accuracy: 0.9492 - val_loss: 0.1749 - val_accuracy: 0.9391
# Epoch 41/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1282 - accuracy: 0.9555 - val_loss: 0.1710 - val_accuracy: 0.9442
# Epoch 42/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1331 - accuracy: 0.9492 - val_loss: 0.1756 - val_accuracy: 0.9391
# Epoch 43/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1191 - accuracy: 0.9517 - val_loss: 0.1770 - val_accuracy: 0.9391
# Epoch 44/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1012 - accuracy: 0.9632 - val_loss: 0.1838 - val_accuracy: 0.9391
# Epoch 45/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1330 - accuracy: 0.9441 - val_loss: 0.1836 - val_accuracy: 0.9391
# Epoch 46/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1155 - accuracy: 0.9581 - val_loss: 0.1861 - val_accuracy: 0.9391
# Epoch 47/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1302 - accuracy: 0.9390 - val_loss: 0.1943 - val_accuracy: 0.9391
# Epoch 48/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1114 - accuracy: 0.9593 - val_loss: 0.1710 - val_accuracy: 0.9442
# Epoch 49/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1066 - accuracy: 0.9543 - val_loss: 0.1626 - val_accuracy: 0.9442
# Epoch 50/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1075 - accuracy: 0.9606 - val_loss: 0.1624 - val_accuracy: 0.9391

# %%
_, train_accuracy = model2.evaluate(X_train, y_train)
test_loss, test_accuracy = model2.evaluate(X_test, y_test)
print(f'Training Accuracy: {train_accuracy * 100:.2f}%')
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0736 - accuracy: 0.9720
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1624 - accuracy: 0.9391
# Training Accuracy: 97.20%
# Test Accuracy: 93.91%

# %%
# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.plot(adam_model.history['accuracy'])
plt.plot(adam_model.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# %% [markdown]
# Stochastic Gradient Descent Optimization technique

# %%
model3 = Sequential()
# Add convolution 2D
model3.add(Conv1D(filters=32,kernel_size=2,activation='relu',input_shape=(30,1)))
model3.add(BatchNormalization())
model3.add(Dropout(0.2))

model3.add(Conv1D(filters=64,kernel_size=2,activation='relu'))
model3.add(BatchNormalization())
model3.add(Dropout(0.5))

model3.add(Flatten())
model3.add(Dense(64,activation='relu'))
model3.add(Dropout(0.5))

model3.add(Dense(1,activation='sigmoid'))


model3.compile(optimizer=SGD(0.9),loss='binary_crossentropy',metrics=['accuracy'])
model3.save('saved_models/model3.pkl')
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 29, 32)            96
#
#  batch_normalization_4 (Bat  (None, 29, 32)            128
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 29, 32)            0
#
#  conv1d_5 (Conv1D)           (None, 28, 64)            4160
#
#  batch_normalization_5 (Bat  (None, 28, 64)            256
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 28, 64)            0
#
#  flatten_2 (Flatten)         (None, 1792)              0
#
#  dense_4 (Dense)             (None, 64)                114752
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 119457 (466.63 KB)
# Trainable params: 119265 (465.88 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
sgd_model = model3.fit(X_train,y_train,epochs=epochs,validation_data=(X_test,y_test),verbose=1)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 2s 48ms/step - loss: nan - accuracy: 0.5057 - val_loss: nan - val_accuracy: 0.5025
# Epoch 2/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 3/50
# 25/25 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 4/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 5/50
# 25/25 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 6/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 7/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 8/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 9/50
# 25/25 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 10/50
# 25/25 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 11/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 12/50
# 25/25 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 13/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 14/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 15/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 16/50
# 25/25 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 17/50
# 25/25 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 18/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 19/50
# 25/25 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 20/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 21/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 22/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 23/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 24/50
# 25/25 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 25/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 26/50
# 25/25 [==============================] - 0s 13ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 27/50
# 25/25 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 28/50
# 25/25 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 29/50
# 25/25 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 30/50
# 25/25 [==============================] - 0s 18ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 31/50
# 25/25 [==============================] - 0s 17ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 32/50
# 25/25 [==============================] - 0s 19ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 33/50
# 25/25 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 34/50
# 25/25 [==============================] - 0s 15ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 35/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 36/50
# 25/25 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 37/50
# 25/25 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 38/50
# 25/25 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 39/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 40/50
# 25/25 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 41/50
# 25/25 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 42/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 43/50
# 25/25 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 44/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 45/50
# 25/25 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 46/50
# 25/25 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 47/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 48/50
# 25/25 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 49/50
# 25/25 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025
# Epoch 50/50
# 25/25 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.4994 - val_loss: nan - val_accuracy: 0.5025

# %%
_, train_accuracy = model3.evaluate(X_train, y_train)
test_loss, test_accuracy = model3.evaluate(X_test, y_test)
print(f'Training Accuracy: {train_accuracy * 100:.2f}%')
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.4994
# 7/7 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.5025
# Training Accuracy: 49.94%
# Test Accuracy: 50.25%

# %%
# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.plot(sgd_model.history['accuracy'])
plt.plot(sgd_model.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# %% [markdown]
# Root Mean Square Propagation

# %%
model4 = Sequential()
model4.add(Conv1D(filters=32,kernel_size=2,activation='relu',input_shape=(30,1)))
model4.add(BatchNormalization())
model4.add(Dropout(0.2))

model4.add(Conv1D(filters=64,kernel_size=2,activation='relu'))
model4.add(BatchNormalization())
model4.add(Dropout(0.5))

model4.add(Flatten())
model4.add(Dense(64,activation='relu'))
model4.add(Dropout(0.5))

model4.add(Dense(1,activation='sigmoid'))


model4.compile(optimizer=RMSprop(),loss='binary_crossentropy',metrics=['accuracy'])
model4.save('saved_models/model4.pkl')
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 29, 32)            96
#
#  batch_normalization_6 (Bat  (None, 29, 32)            128
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 29, 32)            0
#
#  conv1d_7 (Conv1D)           (None, 28, 64)            4160
#
#  batch_normalization_7 (Bat  (None, 28, 64)            256
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 28, 64)            0
#
#  flatten_3 (Flatten)         (None, 1792)              0
#
#  dense_6 (Dense)             (None, 64)                114752
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 119457 (466.63 KB)
# Trainable params: 119265 (465.88 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
rms_model = model4.fit(X_train,y_train,epochs=epochs,validation_data=(X_test,y_test),verbose=1)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 2s 21ms/step - loss: 0.4182 - accuracy: 0.8577 - val_loss: 0.3713 - val_accuracy: 0.9036
# Epoch 2/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.2677 - accuracy: 0.9060 - val_loss: 0.3109 - val_accuracy: 0.9036
# Epoch 3/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.2248 - accuracy: 0.9263 - val_loss: 0.2756 - val_accuracy: 0.9239
# Epoch 4/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.2168 - accuracy: 0.9276 - val_loss: 0.2353 - val_accuracy: 0.9137
# Epoch 5/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.2232 - accuracy: 0.9212 - val_loss: 0.2377 - val_accuracy: 0.9137
# Epoch 6/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.2183 - accuracy: 0.9174 - val_loss: 0.2140 - val_accuracy: 0.9188
# Epoch 7/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.2294 - accuracy: 0.9288 - val_loss: 0.2294 - val_accuracy: 0.9340
# Epoch 8/50
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2269 - accuracy: 0.9263 - val_loss: 0.2491 - val_accuracy: 0.9239
# Epoch 9/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1813 - accuracy: 0.9428 - val_loss: 0.2324 - val_accuracy: 0.9188
# Epoch 10/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2076 - accuracy: 0.9199 - val_loss: 0.2206 - val_accuracy: 0.9239
# Epoch 11/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.1953 - accuracy: 0.9377 - val_loss: 0.2421 - val_accuracy: 0.9340
# Epoch 12/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.2173 - accuracy: 0.9263 - val_loss: 0.2466 - val_accuracy: 0.9340
# Epoch 13/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.1916 - accuracy: 0.9276 - val_loss: 0.2064 - val_accuracy: 0.9188
# Epoch 14/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.1595 - accuracy: 0.9352 - val_loss: 0.2225 - val_accuracy: 0.9492
# Epoch 15/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.1834 - accuracy: 0.9403 - val_loss: 0.2014 - val_accuracy: 0.9289
# Epoch 16/50
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1807 - accuracy: 0.9314 - val_loss: 0.2334 - val_accuracy: 0.9289
# Epoch 17/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1754 - accuracy: 0.9403 - val_loss: 0.2029 - val_accuracy: 0.9340
# Epoch 18/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1662 - accuracy: 0.9416 - val_loss: 0.2011 - val_accuracy: 0.9391
# Epoch 19/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1863 - accuracy: 0.9416 - val_loss: 0.2238 - val_accuracy: 0.9036
# Epoch 20/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1663 - accuracy: 0.9555 - val_loss: 0.1943 - val_accuracy: 0.9492
# Epoch 21/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1562 - accuracy: 0.9454 - val_loss: 0.2100 - val_accuracy: 0.9289
# Epoch 22/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1337 - accuracy: 0.9492 - val_loss: 0.1914 - val_accuracy: 0.9391
# Epoch 23/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1421 - accuracy: 0.9479 - val_loss: 0.2115 - val_accuracy: 0.9239
# Epoch 24/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1810 - accuracy: 0.9454 - val_loss: 0.2120 - val_accuracy: 0.9289
# Epoch 25/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1458 - accuracy: 0.9492 - val_loss: 0.2026 - val_accuracy: 0.9391
# Epoch 26/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1535 - accuracy: 0.9454 - val_loss: 0.1960 - val_accuracy: 0.9391
# Epoch 27/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1720 - accuracy: 0.9416 - val_loss: 0.2020 - val_accuracy: 0.9239
# Epoch 28/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1382 - accuracy: 0.9530 - val_loss: 0.2035 - val_accuracy: 0.9239
# Epoch 29/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1472 - accuracy: 0.9492 - val_loss: 0.1971 - val_accuracy: 0.9492
# Epoch 30/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1511 - accuracy: 0.9454 - val_loss: 0.2009 - val_accuracy: 0.9391
# Epoch 31/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1413 - accuracy: 0.9479 - val_loss: 0.1967 - val_accuracy: 0.9391
# Epoch 32/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1681 - accuracy: 0.9492 - val_loss: 0.2052 - val_accuracy: 0.9340
# Epoch 33/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1683 - accuracy: 0.9492 - val_loss: 0.2104 - val_accuracy: 0.9391
# Epoch 34/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1355 - accuracy: 0.9466 - val_loss: 0.1930 - val_accuracy: 0.9391
# Epoch 35/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1240 - accuracy: 0.9479 - val_loss: 0.1966 - val_accuracy: 0.9492
# Epoch 36/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1328 - accuracy: 0.9517 - val_loss: 0.2134 - val_accuracy: 0.9442
# Epoch 37/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1128 - accuracy: 0.9555 - val_loss: 0.1922 - val_accuracy: 0.9442
# Epoch 38/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1545 - accuracy: 0.9416 - val_loss: 0.1964 - val_accuracy: 0.9442
# Epoch 39/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1438 - accuracy: 0.9504 - val_loss: 0.1965 - val_accuracy: 0.9442
# Epoch 40/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1365 - accuracy: 0.9517 - val_loss: 0.1955 - val_accuracy: 0.9543
# Epoch 41/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1278 - accuracy: 0.9504 - val_loss: 0.1976 - val_accuracy: 0.9492
# Epoch 42/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1386 - accuracy: 0.9416 - val_loss: 0.1962 - val_accuracy: 0.9492
# Epoch 43/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1465 - accuracy: 0.9428 - val_loss: 0.2032 - val_accuracy: 0.9492
# Epoch 44/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1165 - accuracy: 0.9593 - val_loss: 0.1960 - val_accuracy: 0.9442
# Epoch 45/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1608 - accuracy: 0.9530 - val_loss: 0.1956 - val_accuracy: 0.9492
# Epoch 46/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1354 - accuracy: 0.9504 - val_loss: 0.2294 - val_accuracy: 0.9340
# Epoch 47/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1144 - accuracy: 0.9568 - val_loss: 0.2008 - val_accuracy: 0.9442
# Epoch 48/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1287 - accuracy: 0.9517 - val_loss: 0.1868 - val_accuracy: 0.9442
# Epoch 49/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1096 - accuracy: 0.9632 - val_loss: 0.2101 - val_accuracy: 0.9340
# Epoch 50/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1178 - accuracy: 0.9530 - val_loss: 0.2292 - val_accuracy: 0.9442

# %%
_, train_accuracy = model4.evaluate(X_train, y_train)
test_loss, test_accuracy = model4.evaluate(X_test, y_test)
print(f'Training Accuracy: {train_accuracy * 100:.2f}%')
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1003 - accuracy: 0.9517
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2292 - accuracy: 0.9442
# Training Accuracy: 95.17%
# Test Accuracy: 94.42%

# %%
# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.plot(rms_model.history['accuracy'])
plt.plot(rms_model.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# %% [markdown]
# Error Analysis: Make Predictions using the best saved model

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
y_pred = (model.predict(X_test) > 0.5).astype("int32")
accuracy_score(y_test,y_pred)
def make_predictions(model_path, X_test, y_test):
    # Load the model
    model = load_model(model_path)
    y_pred = (model.predict(X_test) > 0.5).astype("int32")

    accuracy_score(y_test,y_pred)
    # Make predictions
    predictions = model.predict(X_test)

    # Convert probabilities to binary labels (0 or 1)
    predictions_labels = np.round(predictions).flatten()

    # Convert y_test to binary labels (assuming it's 0 or 1)
    true_labels = y_test

    # Calculate the confusion matrix
    conf_matrix = confusion_matrix(true_labels, y_pred)
    print("Confusion Matrix:\n", conf_matrix)

    # Calculate classification report
    report = classification_report(true_labels, y_pred)
    print("Classification Report:\n", report)
# Out:
# 7/7 [==============================] - 0s 4ms/step

# %% [markdown]
# Without Optimization

# %%
model_path = 'saved_models/model1.pkl'
make_predictions(model_path, X_test, y_test )
# Out:
# 7/7 [==============================] - 0s 5ms/step
# 7/7 [==============================] - 0s 5ms/step
# Confusion Matrix:
#  [[99  0]
#  [98  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        99
#            1       0.00      0.00      0.00        98
#
#     accuracy                           0.50       197
#    macro avg       0.25      0.50      0.33       197
# weighted avg       0.25      0.50      0.34       197
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# With Adam Optimization

# %%
model_path = 'saved_models/model2.pkl'
make_predictions(model_path, X_test, y_test )
# Out:
# 7/7 [==============================] - 0s 6ms/step
# 7/7 [==============================] - 0s 3ms/step
# Confusion Matrix:
#  [[ 0 99]
#  [ 0 98]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        99
#            1       0.50      1.00      0.66        98
#
#     accuracy                           0.50       197
#    macro avg       0.25      0.50      0.33       197
# weighted avg       0.25      0.50      0.33       197
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# With SGD

# %%
model_path = 'saved_models/model3.pkl'
make_predictions(model_path, X_test, y_test )
# Out:
# 7/7 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 3ms/step
# Confusion Matrix:
#  [[99  0]
#  [98  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        99
#            1       0.00      0.00      0.00        98
#
#     accuracy                           0.50       197
#    macro avg       0.25      0.50      0.33       197
# weighted avg       0.25      0.50      0.34       197
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# With RMSOp

# %%
model_path = 'saved_models/model4.pkl'
make_predictions(model_path, X_test, y_test )
# Out:
# 7/7 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 3ms/step
# Confusion Matrix:
#  [[99  0]
#  [98  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        99
#            1       0.00      0.00      0.00        98
#
#     accuracy                           0.50       197
#    macro avg       0.25      0.50      0.33       197
# weighted avg       0.25      0.50      0.34       197
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
